# %% [markdown]
# # Assignment

# %% [markdown]
# As a Portfolio Manager part of your responsibilities consists of suggesting new investments to your clients. You have access to information about expected returns and standard deviations of 100 different assets, all the information can be found inside of the file. Your business partner has started preparing a Python script that analyzes this data and suggests a portfolio to potential clients. Unfortunately, the file is incomplete and is your duty to complete it (complete lines following the statement TODO)

# %%
# Creates a file with artificial and random ticket information
N = 100
import math
import string
import random
import pandas as pd
random.seed(123)
tickers = [''.join(random.choices(string.ascii_uppercase + string.digits, k = 4)) for n in range(N)] 
# Uniform random numbers for expected returns and volatility
er      = [random.random()*0.1 for n in range(N)]
sd      = [random.random()*0.2 for n in range(N)]

# %%
# TODO: Create a dictionary that has as key the ticker of the company and as value a tuple containing the expected return and the standard deviation
dict={}
for t in range(len(tickers)):
    dict[tickers[t]] = (er[t], sd[t])

dict
# Out:
# {'BDOD': (0.02053425365857603, 0.031237056635783557),
#  '6BTL': (0.03582671689046272, 0.1287647419055195),
#  '4FMM': (0.07780205941264776, 0.019722317126667523),
#  'IAPD': (0.02832995776346611, 0.14278512306624744),
#  'VCLQ': (0.08903160955967432, 0.16749005230036768),
#  '6DF2': (0.09830979223897819, 0.15943444778210317),
#  'A6UJ': (0.016335569610662282, 0.1765904567725927),
#  '41M2': (0.0026714826079936253, 0.12305296567728626),
#  'HVS3': (0.07287206950121948, 0.06675175378010881),
#  'LO1S': (0.0764372512055565, 0.036488080982747584),
#  'YWX6': (0.09009222434862069, 0.13157050967917477),
#  'RYNB': (0.06724659589033984, 0.19485216502641867),
#  '1G36': (0.07800997733524101, 0.1316152508263518),
#  'XGMO': (0.036552009868623704, 0.020786532889769463),
#  'CQUM': (0.010081332278536826, 0.008701041662681841),
#  'GDWA': (0.09999133401695609, 0.03044732161836925),
#  'MIT0': (0.060469327942576125, 0.16057885832185453),
#  '6W98': (0.027045033962470013, 0.02718771961637878),
#  'WIRG': (0.089276309247526, 0.14118500152427668),
#  '9Q1B': (0.007359212905995738, 0.1167458806961219),
#  'EGJM': (0.005678103055556505, 0.07295816914753116),
#  'JPPD': (0.025485106826686633, 0.08416032002239118),
#  'CMDP': (0.013009117731505471, 0.052638751691091334),
#  'ATCY': (0.04107476777789437, 0.08219488388983598),
#  'O9JR': (0.062107826963054315, 0.036805721422300056),
#  '1MMX': (0.051941951209620155, 0.10582797057206397),
#  '85PZ': (0.05537166138297664, 0.13216356922171255),
#  'YNIC': (0.01193780129122054, 0.10994856967273972),
#  '5CST': (0.05349347004365425, 0.19826545842717158),
#  'FX61': (0.09751611718264387, 0.1850077346002668),
#  'OE9S': (0.03297893426336253, 0.17805620220355167),
#  'W2NC': (0.07992474198416781, 0.1207814480502083),
#  'EYM5': (0.06379859959069122, 0.028805180668450128),
#  '09YK': (0.07620594872751336, 0.15177832334759206),
#  '2BS5': (0.06579474755258273, 0.188707294559269),
#  'SEST': (0.043950779703815536, 0.12012435212899907),
#  'N6MJ': (0.023497705910616173, 0.09080926166527506),
#  'SHLO': (0.009356901674573537, 0.13104923553212153),
#  '7CHH': (0.011324530556289637, 0.1253842037894524),
#  '96GU': (0.010092621246200107, 0.16553555213097845),
#  'DLMT': (0.07673499393533437, 0.09588013146735859),
#  'MYAM': (0.05349332088665481, 0.036529451268852965),
#  '1XCZ': (0.031145885364194516, 0.19659133178875396),
#  'VQDV': (0.0031235286654776374, 0.10002666811437466),
#  '0HWC': (0.06752073469432877, 0.0010481930831033105)}

# %%
# TODO: Create a third element for each key in the dictionary that consists of the ratio between the expected return and the standard  (sharpe ratio)
# Hint: Remember that tuples are immutable but dictionaries are not

for key, value in dict.items():
    temp_value = (value[0], value[1], value[0]/value[1])
    dict[key] = temp_value

dict
# Out:
# {'BDOD': (0.02053425365857603, 0.031237056635783557, 0.6573683909467017),
#  '6BTL': (0.03582671689046272, 0.1287647419055195, 0.27823390440801254),
#  '4FMM': (0.07780205941264776, 0.019722317126667523, 3.9448741703604253),
#  'IAPD': (0.02832995776346611, 0.14278512306624744, 0.19840973033529533),
#  'VCLQ': (0.08903160955967432, 0.16749005230036768, 0.5315635665335503),
#  '6DF2': (0.09830979223897819, 0.15943444778210317, 0.6166157540391572),
#  'A6UJ': (0.016335569610662282, 0.1765904567725927, 0.09250539303887008),
#  '41M2': (0.0026714826079936253, 0.12305296567728626, 0.021710022129818048),
#  'HVS3': (0.07287206950121948, 0.06675175378010881, 1.0916877141726042),
#  'LO1S': (0.0764372512055565, 0.036488080982747584, 2.0948553376018273),
#  'YWX6': (0.09009222434862069, 0.13157050967917477, 0.6847448152956471),
#  'RYNB': (0.06724659589033984, 0.19485216502641867, 0.34511598001090893),
#  '1G36': (0.07800997733524101, 0.1316152508263518, 0.5927122947033275),
#  'XGMO': (0.036552009868623704, 0.020786532889769463, 1.7584466857680512),
#  'CQUM': (0.010081332278536826, 0.008701041662681841, 1.1586351001828843),
#  'GDWA': (0.09999133401695609, 0.03044732161836925, 3.284076519776047),
#  'MIT0': (0.060469327942576125, 0.16057885832185453, 0.3765709170840851),
#  '6W98': (0.027045033962470013, 0.02718771961637878, 0.9947518344339991),
#  'WIRG': (0.089276309247526, 0.14118500152427668, 0.6323356467306832),
#  '9Q1B': (0.007359212905995738, 0.1167458806961219, 0.06303616763276683),
#  'EGJM': (0.005678103055556505, 0.07295816914753116, 0.0778268303865277),
#  'JPPD': (0.025485106826686633, 0.08416032002239118, 0.3028161824943895),
#  'CMDP': (0.013009117731505471, 0.052638751691091334, 0.24713955619329694),
#  'ATCY': (0.04107476777789437, 0.08219488388983598, 0.49972414138264365),
#  'O9JR': (0.062107826963054315, 0.036805721422300056, 1.6874503355183272),
#  '1MMX': (0.051941951209620155, 0.10582797057206397, 0.4908149606275411),
#  '85PZ': (0.05537166138297664, 0.13216356922171255, 0.4189631205410869),
#  'YNIC': (0.01193780129122054, 0.10994856967273972, 0.10857623093009057),
#  '5CST': (0.05349347004365425, 0.19826545842717158, 0.2698073101992392),
#  'FX61': (0.09751611718264387, 0.1850077346002668, 0.5270921099236208),
#  'OE9S': (0.03297893426336253, 0.17805620220355167, 0.1852164308528911),
#  'W2NC': (0.07992474198416781, 0.1207814480502083, 0.6617302845296528),
#  'EYM5': (0.06379859959069122, 0.028805180668450128, 2.214830739130508),
#  '09YK': (0.07620594872751336, 0.15177832334759206, 0.5020871692790535),
#  'NFIH': (0.04974939975512534, 0.15268574602692228, 0.32582871060114077),
#  'XPUO': (0.0422722079349028, 0.19401717225822604, 0.2178786931222812),
#  '9RBF': (0.08661014646228991, 0.06756852816953222, 1.2818119442380258),
#  '06EQ': (0.0800635084296704, 0.09617767658301513, 0.8324541751698911),
#  '5TAS': (0.015395734585936405, 0.047055597755482986, 0.3271817875088511),
#  'KH7D': (0.06660731959890058, 0.14575916932934588, 0.4569682984979144),
#  '31VL': (0.05498796717999626, 0.16812629558553913, 0.3270634554130144),
#  'CY8G': (0.08975138949549881, 0.13817105519141695, 0.6495672293387398),
#  'ER4A': (0.0062730971343634145, 0.14223519827991873, 0.0441036902976573),
#  '2DBF': (0.05782904398820602, 0.0287423154250009, 2.0119827902906056),
#  'Q7XC': (0.01898195400887631, 0.18665887570458656, 0.10169328373603768),
#  'FQDY': (0.05693440118308421, 0.02806063018317542, 2.028977995555528),
#  'M833': (0.08171744857860667, 0.1614474127427447, 0.5061552067657955),
#  'IPYD': (0.04340270438130278, 0.03344811154225833, 1.2976130005566329),
#  'ALO2': (0.05347987185338463, 0.13717839032323859, 0.3898563886583594),
#  '3CC7': (0.03651275714829998, 0.14887048126645744, 0.2452652590203375),
#  'KE22': (0.09448347600619021, 0.03576557453184048, 2.641743554883365),
#  'V144': (0.08624100775732634, 0.11163250935192244, 0.7725438428106173),
#  'JP9N': (0.008969085245816666, 0.049804949028240536, 0.1800842169466129),
#  'W45V': (0.00427317316750031, 0.19056269474927537, 0.022423975338523385),
#  'MYAM': (0.05349332088665481, 0.036529451268852965, 1.464388843208991),
#  '1XCZ': (0.031145885364194516, 0.19659133178875396, 0.1584295964669599),
#  'VQDV': (0.0031235286654776374, 0.10002666811437466, 0.03122695901363089),
#  '0HWC': (0.06752073469432877, 0.0010481930831033105, 64.4163139241722)}

# %%
# TODO: Find the ten companies with the largest sharpe ratios
# Hint: Store the tickers of the 10 largest sharpe ratios while traversing all the companies, update if you have found a new and larger sharpe ratio
#       you can use the functions max and min, as well as the following argmin and argmax functions that return the index of the maximum and minimum in
#       the array
def argmax(iterable):
    return max(enumerate(iterable), key=lambda x: x[1])[0]

def argmin(iterable):
    return min(enumerate(iterable), key=lambda x: x[1])[0]

largest_tickers = []
largest_sr      = []
n = 10 # Number of companies to pick
for key, value in dict.items():

    sharpe_ratio = value[2]
    # Is the sharpe ratio in the top 10?
    if len(largest_sr) < n:
        largest_sr.append(sharpe_ratio)
        largest_tickers.append(key)
    else:
        # Check if my sharpe ratio is in the top 10
        min_sr = min(largest_sr)
        id_sr  = argmin(largest_sr)

        if sharpe_ratio > min_sr:
            largest_sr.pop(id_sr)
            largest_tickers.pop(id_sr)

            largest_sr.append(sharpe_ratio)
            largest_tickers.append(key)

print("Companies suggestion")
for i in range(n):
    print(f"{largest_tickers[i]} => { round(largest_sr[i],2) }")
# Out:
# Companies suggestion
# 4FMM => 3.94
# LO1S => 2.09
# GDWA => 3.28
# EYM5 => 2.21
# N7EJ => 2.39
# AX0R => 2.49
# B9F5 => 3.95
# FQDY => 2.03
# KE22 => 2.64
# 0HWC => 64.42
